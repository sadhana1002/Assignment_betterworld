# %%
#Import necessary libraries
import pandas as pd
import numpy as np
import os

# %%
# SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# %%
# Create Engine and Pass in MySQL Connection
engine = create_engine("mysql://root:Mkashi029@@localhost:3306/kiva")
conn = engine.connect()

# %%
# Query All Records in the the Database
loan_data = pd.read_sql("SELECT * FROM loans", conn)

# %%
loan_data.head()
# Out:
#    loan_id  status  sector_name          activity_name country_code  \
# 0       84  funded         Food           Butcher Shop           UG
# 1       85  funded         Food  Food Production/Sales           UG
# 2       86  funded  Agriculture           Animal Sales           UG
# 3       88  funded     Clothing         Clothing Sales           UG
# 4       89  funded         Food  Food Production/Sales           UG
#
#   country_name         posted_time       disburse_time         raised_time  \
# 0       Uganda 2006-04-16 07:10:50 2005-04-14 05:27:55 2005-03-31 06:27:55
# 1       Uganda 2006-04-16 07:10:50 2005-04-14 05:27:55 2005-03-31 06:27:55
# 2       Uganda 2006-04-16 07:10:50 2005-04-14 05:27:55 2005-03-31 06:27:55
# 3       Uganda 2006-04-16 07:10:50 2005-04-14 05:27:55 2005-03-31 06:27:55
# 4       Uganda 2006-04-16 07:10:50 2005-04-14 05:27:55 2005-03-31 06:27:55
#
#    lender_term  num_lenders_total repayment_interval  shortage_fund  \
# 0            6                  5             bullet            0.0
# 1            6                  3             bullet            0.0
# 2            6                  3             bullet            0.0
# 3            6                  4             bullet            0.0
# 4            6                  6             bullet            0.0
#
#    female_count  male_count  borrower_count  funded_amount_usd  \
# 0             0           1               1              500.0
# 1             0           1               1              500.0
# 2             0           1               1              500.0
# 3             1           0               1              300.0
# 4             1           0               1              500.0
#
#    loan_amount_usd
# 0            500.0
# 1            500.0
# 2            500.0
# 3            300.0
# 4            500.0
